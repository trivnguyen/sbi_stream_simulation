# %%
import numpy as np
from rotation_matrix import obs_from_pos6d
import matplotlib.pyplot as plt

# %%
R_phi12_radec = np.array([[0.83697865, 0.29481904, -0.4610298], 
                          [0.51616778, -0.70514011, 0.4861566], 
                          [0.18176238, 0.64487142, 0.74236331]])

# %%
from importlib import reload
reload(temp)
# Out:
# <module 'temp' from '/nfs/home2/rutong/stellar_stream/SBI-streameeeee/sims/temp.py'>

# %%
parameters, phi1, phi2, dist, pm1, pm2, vr = temp.read_observables_hdf5('sim14621.hdf5')
plt.scatter(phi1,phi2,s=1)
# plt.xlim(-25, 25)
# plt.ylim(-50, 70)
plt.xlabel("phi1 [deg]")
plt.ylabel("phi2 [deg]")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
data1 = np.genfromtxt('final_stream/final_stream_1.txt')

# %%
#added
data2 = np.genfromtxt('final_stream/final_stream_2.txt')
data3 = np.genfromtxt('final_stream/final_stream_3.txt')
data4 = np.genfromtxt('final_stream/final_stream_4.txt')
data5 = np.genfromtxt('final_stream/final_stream_5.txt')
data6 = np.genfromtxt('final_stream/final_stream_6.txt')

# %%
phi1,phi2,dist,pm1,pm2,vr = obs_from_pos6d(data[:,:3],data[:,3:6],R_phi12_radec)

# positions=[]
# for i in range(100):
#     pair = [phi1[i], phi2[i]]
#     positions.extend(pair)

# %%
phi11,phi21,dist1,pm11,pm21,vr1 = obs_from_pos6d(data1[:,:3],data1[:,3:6],R_phi12_radec)

# %%
#added
phi12,phi22,dist2,pm12,pm22,vr2 = obs_from_pos6d(data2[:,:3],data2[:,3:6],R_phi12_radec)
phi13,phi23,dist3,pm13,pm23,vr3 = obs_from_pos6d(data3[:,:3],data3[:,3:6],R_phi12_radec)
phi14,phi24,dist4,pm14,pm24,vr4 = obs_from_pos6d(data4[:,:3],data4[:,3:6],R_phi12_radec)
phi15,phi25,dist5,pm15,pm25,vr5 = obs_from_pos6d(data5[:,:3],data5[:,3:6],R_phi12_radec)
phi16,phi26,dist6,pm16,pm26,vr6 = obs_from_pos6d(data6[:,:3],data6[:,3:6],R_phi12_radec)

# %%
# plt.scatter(phi11,phi21,s=1, label='M_sat=1e7')
# plt.xlim(-50, 120)
# plt.ylim(-50, 70)
# plt.xlabel("phi1 [deg]")
# plt.ylabel("phi2 [deg]")
# plt.legend()
# plt.show()
#added
plt.scatter(phi12,phi22,s=1, label='M_sat=1e8')
plt.xlim(-50, 120)
plt.ylim(-50, 70)
plt.xlabel("phi1 [deg]")
plt.ylabel("phi2 [deg]")
plt.legend()
plt.show()

# plt.scatter(phi13,phi23,s=1, label='M_sat=1e9')
# plt.xlim(-50, 120)
# plt.ylim(-50, 70)
# plt.xlabel("phi1 [deg]")
# plt.ylabel("phi2 [deg]")
# plt.legend()
# plt.show()

# plt.scatter(phi14,phi24,s=1, label='M_sat=1e10')
# plt.xlim(-50, 120)
# plt.ylim(-50, 70)
# plt.xlabel("phi1 [deg]")
# plt.ylabel("phi2 [deg]")
# plt.legend()
# plt.show()

# plt.scatter(phi15,phi25,s=1, label='M_sat=1')
# plt.xlim(-50, 120)
# plt.ylim(-50, 70)
# plt.xlabel("phi1 [deg]")
# plt.ylabel("phi2 [deg]")
# plt.legend()
# plt.show()

# plt.scatter(phi16,phi26,s=1, label='M_sat=10')
# plt.xlim(-50, 120)
# plt.ylim(-50, 70)
# plt.xlabel("phi1 [deg]")
# plt.ylabel("phi2 [deg]")
# plt.legend()
# plt.show()

plt.xlabel("phi1 [deg]")
plt.ylabel("phi2 [deg]")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
for i in range(5):
    data = np.genfromtxt(f'final_stream/final_stream_{4-i}.txt')
    phi1,phi2,dist,pm1,pm2,vr = obs_from_pos6d(data[:,:3],data[:,3:6],R_phi12_radec)
    # plt.xlim(-30, 100)
    # plt.ylim(-18, 8)
    plt.scatter(phi1,phi2,s=1, label=f'vz = {-20*i-20}')

plt.xlabel("phi1 [deg]")
plt.ylabel("phi2 [deg]")
plt.legend()
plt.show()

# %%
# data = np.genfromtxt(f'final_stream/final_stream_{35}.txt')
# phi1,phi2,dist,pm1,pm2,vr = obs_from_pos6d(data[:,:3],data[:,3:6],R_phi12_radec)
# plt.xlim(-60, 160)
# plt.ylim(-40, 8)
# plt.scatter(phi1,phi2,s=1)
